# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pickle 
import pandas as pd

# %%
#读取32个通道的EEG数据，每个通道包含32×40=1280个信号样本（人次×每人次40实验）
#每个样本向量大小为8064点（63s*128Hz）
for eegCH in range(1,33,1):
    file_path = "./dump_file/CH{}_df_EEG_x".format(eegCH)
    locals()['CH{}_df_EEG_x'.format(eegCH)] = pickle.load(open(file_path,"rb"))

#读取1个通道的GSR数据，每个通道包含32×40=1280个信号样本
#每个样本向量大小为8064点（63s*128Hz）
all_df_GSR_x = pickle.load(open("./dump_file/all_df_GSR_x","rb"))

#读取1个通道的RSP数据，每个通道包含32×40=1280个信号样本
#每个样本向量大小为8064点（63s*128Hz）
all_df_RSP_x = pickle.load(open("./dump_file/all_df_RSP_x","rb"))

#读取1个通道的BVP数据，每个通道包含32×40=1280个信号样本
#每个样本向量大小为8064点（63s*128Hz）
all_df_BVP_x = pickle.load(open("./dump_file/all_df_BVP_x","rb"))

# %%
#画图DPI设定
DPI_SET = 100
plt.figure(dpi = DPI_SET)
plt.plot(CH10_df_EEG_x.iloc[0,4000:4200])
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show()

# %%
#画图DPI设定
DPI_SET = 100
plt.figure(dpi = DPI_SET)
plt.plot(all_df_RSP_x.iloc[0,4000:4300])
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show()
